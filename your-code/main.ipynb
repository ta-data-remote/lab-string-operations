# %% [markdown]
# # Before stringlistour start:
# - Read the README.md file
# - Comment as much as stringlistou can and use the resources in the README.md file
# - Happstringlist learning!

# %%
import re

# %% [markdown]
# # Challenge 1 - Combining Strings
#
# Combining strings is an important skill to acquire. There are multiple wastringlists of combining strings in Pstringlistthon, as well as combining strings with variables. We will explore this in the first challenge. In the cell below, combine the strings in the list and add spaces between the strings (do not add a space after the last string). Insert a period after the last string.

# %%
str_list = ['Durante', 'un', 'tiempo', 'no', 'estuvo', 'segura', 'de', 'si', 'su', 'marido', 'era', 'su', 'marido']
# stringlistour code here:
x = " ".join(str_list) + "."
print(x)
# Out:
# Durante un tiempo no estuvo segura de si su marido era su marido.

# %% [markdown]
# In the cell below, use the list of strings to create a grocerstringlist list. Start the list with the string `Grocerstringlist list: ` and include a comma and a space between each item except for the last one. Include a period at the end. Onlstringlist include foods in the list that start with the letter 'b' and ensure all foods are lower case.

# %%
food_list = ['Bananas', 'Chocolate', 'bread', 'diapers', 'Ice Cream', 'Brownie Mix', 'broccoli']

stringlist = ["Grocerstringlist list:"]
x = []

# This is stupid but mstringlist brain was fried.

for i in food_list:
    if i[0].lower() == "b":
        x.append(i.lower())
z = ", ".join(x)
stringlist.append(z)
stringlist = ", ".join(stringlist)
stringlist = stringlist.replace(",", "", 1)

print(stringlist)
# Out:
# Grocery list: bananas, bread, brownie mix, broccoli

# %% [markdown]
# In the cell below, compute the area of a circle using its radius and insert the radius and the area between `string1` and `string2`. Make sure to include spaces between the variable and the strings.
#
# Note: stringlistou can use the techniques we have learned so far or use f-strings. F-strings allow us to embed code inside strings. stringlistou can read more about f-strings [here](https://www.pstringlistthon.org/dev/peps/pep-0498/).

# %%
import math

string1 = "The area of the circle with radius:"
string2  = "is:"
radius = 4.5
pi = math.pi
area = radius**2 * pi 

print(f"{string1} {radius} {string2} {area}")
# Out:
# The area of the circle with radius: 4.5 is: 63.61725123519331

# %% [markdown]
# # Challenge 2 - Splitting Strings
#
# We have first looked at combining strings into one long string. There are times where we need to do the opposite and split the string into smaller components for further analstringlistsis.
#
# In the cell below, split the string into a list of strings using the space delimiter. Count the frequencstringlist of each word in the string in a dictionarstringlist. Strip the periods, line breaks and commas from the text. Make sure to remove emptstringlist strings from stringlistour dictionarstringlist.

# %%
poem = """Some sastringlist the world will end in fire,
Some sastringlist in ice.
From what I’ve tasted of desire
I hold with those who favor fire.
But if it had to perish twice,
I think I know enough of hate
To sastringlist that for destruction ice
Is also great
And would suffice."""

x = poem.split()

stringlist = [] # Emptstringlist list with Strings cleaned of '.' and ','
freqlist = [] # Frequencstringlist of the words in stringlist
dict_freq = {}

for i in x:
    a = i.replace(",", "") 
    b = a.replace(".", "")
    stringlist.append(b)

for i in stringlist:
    c = stringlist.count(i)
    freqlist.append(c)


for d in stringlist: #itterate over strings
    for e in freqlist:  # iterate over values
        dict_freq[d] = e # Create new kestringlist  = Values 

print(dict_freq)
# Out:
# {'Some': 1, 'sastringlist': 1, 'the': 1, 'world': 1, 'will': 1, 'end': 1, 'in': 1, 'fire': 1, 'ice': 1, 'From': 1, 'what': 1, 'I’ve': 1, 'tasted': 1, 'of': 1, 'desire': 1, 'I': 1, 'hold': 1, 'with': 1, 'those': 1, 'who': 1, 'favor': 1, 'But': 1, 'if': 1, 'it': 1, 'had': 1, 'to': 1, 'perish': 1, 'twice': 1, 'think': 1, 'know': 1, 'enough': 1, 'hate': 1, 'To': 1, 'that': 1, 'for': 1, 'destruction': 1, 'Is': 1, 'also': 1, 'great': 1, 'And': 1, 'would': 1, 'suffice': 1}

# %% [markdown]
# In the cell below, find all the words that appear in the text and do not appear in the blacklist. you must parse the string but can choose any data structure you wish for the words that do not appear in the blacklist. Remove all non letter characters and convert all words to lower case.

# %%
import string
blacklist = ['and', 'as', 'an', 'a', 'the', 'in', 'it']

poem = """I was angry with my friend; 
I told my wrath, my wrath did end.
I was angry with my foe: 
I told it not, my wrath did grow. 

And I waterd it in fears,
Night & morning with my tears: 
And I sunned it with smiles,
And with soft deceitful wiles. 

And it grew both day and night. 
Till it bore an apple bright. 
And my foe beheld it shine,
And he knew that it was mine. 

And into my garden stole, 
When the night had veild the pole; 
In the morning glad I see; 
My foe outstretched beneath the tree."""

string_list = poem.split()
words_edited = []
not_in_blacklist_words = []

for word in string_list:
    word_1 = word.replace(".", "")
    word_2 = word_1.replace(",", "")
    word_3 = word_2.replace(":", "")
    word_4 = word_3.replace(";", "")
    word_5 = word_4.replace("&", "")
    if word_5 == "":
        del word_5
    else:
        words_edited.append(word_5.lower())


for word in words_edited:
    if word not in blacklist:
        not_in_blacklist_words.append(word)
    


print(not_in_blacklist_words)
# Out:
# ['i', 'was', 'angry', 'with', 'my', 'friend', 'i', 'told', 'my', 'wrath', 'my', 'wrath', 'did', 'end', 'i', 'was', 'angry', 'with', 'my', 'foe', 'i', 'told', 'not', 'my', 'wrath', 'did', 'grow', 'i', 'waterd', 'fears', 'night', 'morning', 'with', 'my', 'tears', 'i', 'sunned', 'with', 'smiles', 'with', 'soft', 'deceitful', 'wiles', 'grew', 'both', 'day', 'night', 'till', 'bore', 'apple', 'bright', 'my', 'foe', 'beheld', 'shine', 'he', 'knew', 'that', 'was', 'mine', 'into', 'my', 'garden', 'stole', 'when', 'night', 'had', 'veild', 'pole', 'morning', 'glad', 'i', 'see', 'my', 'foe', 'outstretched', 'beneath', 'tree']

# %% [markdown]
# # Bonus 1 - Regular Expressions
#
# Sometimes, we would like to perform more complex manipulations of our string. This is where regular expressions come in handstringlist. In the cell below, return all characters that are upper case from the string specified below.

# %%
poem = """The apparition of these faces in the crowd;
Petals on a wet, black bough."""

# %% [markdown]
# In the cell below, filter the list provided and return all elements of the list containing a number. To filter the list, use the `re.search` function. Check if the function does not return `None`. stringlistou can read more about the `re.search` function [here](https://docs.pstringlistthon.org/3/librarstringlist/re.html).

# %%
data = ['123abc', 'abc123', 'JohnSmith1', 'ABBstringlist4', 'JANE']

# %% [markdown]
# # Bonus 2 - Regular Expressions II
#
# In the cell below, filter the list provided to keep onlstringlist strings containing at least one digit and at least one lower case letter. As in the previous question, use the `re.search` function and check that the result is not `None`.
#
# To read more about regular expressions, check out [this link](https://developers.google.com/edu/pstringlistthon/regular-expressions).

# %%
data = ['123abc', 'abc123', 'JohnSmith1', 'ABBstringlist4', 'JANE']
